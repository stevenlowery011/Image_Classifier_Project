# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np
from torch import nn
from torch import optim
import torch.nn.functional as F
from collections import OrderedDict
import time
from workspace_utils import active_session
import os
from PIL import Image
from math import ceil

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# DONE: Define your transforms for the training, validation, and testing sets
train_transform = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.RandomRotation(30),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
valid_transform = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])
test_transform = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# DONE: Load the datasets with ImageFolder
train_dataset = datasets.ImageFolder(train_dir, transform=train_transform)
valid_dataset = datasets.ImageFolder(valid_dir, transform=valid_transform)
test_dataset = datasets.ImageFolder(test_dir, transform=test_transform)

# DONE: Using the image datasets and the trainforms, define the dataloaders
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle = True)
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=32, shuffle = True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle = True)

# Testing this cell
images, labels = next(iter(test_dataloader))
fig, ax = plt.subplots()
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
image = images[0].numpy().transpose((1, 2, 0))
image = std * image + mean
image = np.clip(image, 0, 1)
ax.imshow(image)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    
train_dataset.class_to_idx = cat_to_name
valid_dataset.class_to_idx = cat_to_name
test_dataset.class_to_idx = cat_to_name

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students! You can also ask questions on the forums or join the instructors in office hours.
#
# Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.

# %% [markdown]
# ## Functions and Classes here:

# %%
# Defining class for a fully-connected network
class Network(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers, drop_p=0.5):
        ''' Builds a feedforward network with arbitrary hidden layers.
        
            Arguments
            ---------
            input_size: integer, size of the input
            output_size: integer, size of the output layer
            hidden_layers: list of integers, the sizes of the hidden layers
            drop_p: float between 0 and 1, dropout probability
        '''
        super().__init__()
        # Add the first layer, input to a hidden layer
        self.hidden_layers = nn.ModuleList([nn.Linear(input_size, hidden_layers[0])])
        
        # Add a variable number of more hidden layers
        layer_sizes = zip(hidden_layers[:-1], hidden_layers[1:])
        self.hidden_layers.extend([nn.Linear(h1, h2) for h1, h2 in layer_sizes])
        
        self.output = nn.Linear(hidden_layers[-1], output_size)
        
        self.dropout = nn.Dropout(p=drop_p)
        
    def forward(self, x):
        ''' Forward pass through the network, returns the output logits '''
        
        # Forward through each layer in `hidden_layers`, with ReLU activation and dropout
        for linear in self.hidden_layers:
            x = F.relu(linear(x))
            x = self.dropout(x)
        
        x = self.output(x)
        
        return F.log_softmax(x, dim=1)

# %%
def network_train(model, epochs, learnrate, train_dataloader, test_dataloader, total_steps, use_GPU):
    """
    Train a neural network model and update the output window with output loss, accuracy, and time.

    Parameters:
        model - torchvision.models.model, the neural network model
        epochs - int, number of training epochs (iterations)
        learnrate - the neural network learning rate
        train_dataloader - the dataloader for the training set
        test_dataloader - the dataloader for the test set
        total_steps - int, the total number of iterations in the training dataset
        use_GPU - bool, use GPU if True
    Returns:
        accuracy - float, the accuracy of the model
    """
    print("\nTraining network...")
    
    # Select the GPU if it is available and if use_GPU is True
    if(use_GPU==True):
        if torch.cuda.is_available():
            device = torch.device("cuda:0")
        else:
            print("GPU not available. Using CPU instead.")
            device = torch.device("cpu")
    # Otherwise use the CPU
    else:
        device = torch.device("cpu")
    print(f"Device = {device}\n")
    
    # Set up the training parameters
    steps = 0
    running_loss = 0
    print_every = total_steps

    # Define the criterion and optimizer given the model and learning rate
    criterion = nn.NLLLoss()
    optimizer = optim.Adam(model.classifier.parameters(), lr=learnrate)

    # Send the model to the correct processor
    model.to(device)

    # Record the start time before training
    start = time.time()
    
    # Train the network all the way through the training set for each epoch
    for e in range(epochs):
        steps = 0

        # Put the model in training mode
        model.train()

        # Loop through the training dataloader and train on all images
        for image, label in train_dataloader:
            steps += 1
            # If the dataloader is too long to process, the number of steps can be reduced and break mid-training
            if steps > total_steps:
                break

            # Print an update to the output window to show that the training is ongoing
            print("Epoch: {:^3}/{:^3}.. ".format(e+1, epochs),
                  "Step: {:^3}/{:^3}..".format(steps, total_steps),
                  "-- Time: {:>10.3f}  ".format(time.time()-start),
                  "(Model is training. Validation after {} more training steps.)".format(print_every - steps))

            # Send the data to the processor
            image, label = image.to(device), label.to(device)

            # Zero out the gradients before doing forward pass and back-propagation
            optimizer.zero_grad()

            # Do a forward pass, calculate loss, and do a back-propagation
            output = model.forward(image)
            loss = criterion(output, label)
            loss.backward()

            # Optimize the weights and biases
            optimizer.step()

            # Update the loss value
            running_loss += loss.item()

            # Do a validation pass once every so many loops
            if steps % print_every == 0:
                # Put the model in eval mode and turn off gradients
                model.eval()
                with torch.no_grad():
                    # Do a validation
                    test_loss, accuracy = validation(model, test_dataloader, criterion, device)
                # Print the results to the output window
                print("Epoch: {:^3}/{:^3}.. ".format(e+1, epochs),
                      "Step: {:^3}/{:^3}..".format(steps, total_steps),
                      "-- Time: {:>10.3f}".format(time.time()-start),
                      "Training Loss: {:.3f}.. ".format(running_loss/print_every),
                      "Test Loss: {:.3f}.. ".format(test_loss/len(test_dataloader)),
                      "Test Accuracy: {:.3f}".format(accuracy/len(test_dataloader)),
                      )
                # Clear the running loss and put the model back in training mode
                running_loss = 0
                model.train()

    # Return the accuracy in terms of a percentage
    return accuracy/len(test_dataloader)

# %%
def validation(model, testloader, criterion, processor):
    """
    Validates the model using the test images.

    Parameters:
        model - torchvision.models.model, the neural network model
        testloader - the dataloader for the test set
        criterion - the output loss criterion
        processor - torch.device, CPU of GPU
    Returns:
        test_loss - torch.tensor, the output loss from the validation pass
        accuracy - torch.tensor, the percentage of correctly classified test images
    """
    test_loss = 0
    accuracy = 0

    # Send the model to the desired processor
    model.to(processor)

    # Iterate through the test dataloader and do a validation pass on all images
    for images, labels in testloader:
        images, labels = images.to(processor), labels.to(processor)

        # Do a forward pass
        output = model.forward(images)

        # Calculate the loss based on the criterion
        test_loss += criterion(output, labels).item()

        # Since the output is log-loss, the probabilities are the e^x of the output
        ps = torch.exp(output)

        # Check how many of the most probable output results match the labels
        equality = (labels.data == ps.max(dim=1)[1])
        accuracy += equality.type(torch.FloatTensor).mean()
    
    return test_loss, accuracy

# %%
def load_checkpoint(filepath):
    """
    Load a model checkpoint.

    Parameters:
        filepath - string, the path to the saved checkpoint to be loaded
    Returns:
        model - the trained model from the checkpoint file
        accuracy - float, the accuracy of the trained model
    """
    checkpoint = torch.load(filepath)
    model_name = checkpoint['transfer_model_name']
    
    #-------Following line only works in Jupyter notebook---------
    hyperparameters['architecture'] = model_name
    #-------Remove the above line if using in script or module----
    
    model = get_model(model_name)
    
    classifier = Network(checkpoint['input_size'],
                         checkpoint['output_size'],
                         checkpoint['hidden_layers'],
                         checkpoint['drop_p'])
    model.classifier = classifier
    model.load_state_dict(checkpoint['state_dict'])
    hidden_layers = checkpoint['hidden_layers']
    dropout_probability = checkpoint['drop_p']
    learnrate = checkpoint['learnrate']
    epochs = checkpoint['epochs']
    accuracy = checkpoint['model_accuracy']
    
    return model, accuracy

# %%
def save_checkpoint(filepath, model, transfer_model_name, input_size, output_size, hyperparams, model_accuracy):
    """
    Save a model checkpoint.

    Parameters:
        filepath - string, the filepath of the checkpoint to be saved
        model - torchvision.models.model, the trained model to be saved
        transfer_model_name - string, the name of the transfer model 
        input_size - int, the input size of the classifier's hidden layers
        output_size - int, the output size of the classifier (number of categories)
        hyperparams - dictionary, the hyperparameters of the model training, including epochs, dropout probability, and learnrate
        model_accuracy - float, the accuracy of the trained model
    Returns:
        None
    """
    checkpoint = {'transfer_model_name': transfer_model_name,
                  'input_size': input_size,
                  'output_size': output_size,
                  'hidden_layers': hyperparams['hidden_layers'],
                  'drop_p': hyperparams['dropout_probability'],
                  'learnrate': hyperparams['learnrate'],
                  'epochs': hyperparams['epochs'],
                  'model_accuracy': model_accuracy,
                  'state_dict': model.state_dict()}

    torch.save(checkpoint, filepath)

# %%
def get_model(model_name):
    """
    Parse the given model name and create a new transfer model.
    Parameters:
        model_name - string, name of the transfer model from torchvision.models
    Returns:
        model - torchvision.models.model, the transfer network model with gradients disabled
    """
    if model_name=='vgg16':
        model = models.vgg16(pretrained=True)
    elif model_name=='vgg13':
        model = models.vgg13(pretrained=True)
    elif model_name=='vgg11':
        model = models.vgg11(pretrained=True)
    elif model_name=='alexnet':
        model = models.alexnet(pretrained=True)
    else:
        print("\nINPUT ERROR: must select from one of these models: vgg16, vgg13, vgg11, alexnet\n")

    for param in model.parameters():
        param.requires_grad = False

    return model

# %% [markdown]
# ## Define Hyperparameters Here:

# %%
# define the hyperparameters
hyperparameters = {'architecture': 'vgg11',
                   'hidden_layers': [128, 64, 32],
                   'dropout_probability': 0.2,
                   'learnrate': 0.001,
                   'epochs': 2}

# %% [markdown]
# ## Load a pre-trained network here:

# %%
# Load a pre-trained network into memory and freeze the parameters
model = models.vgg11(pretrained=True)
hyperparameters['architecture'] = 'vgg11'
for param in model.parameters():
    param.requires_grad = False
    
# create the classifier for this pre-trained network

# Check the classifier of the given model and find the first Linear module to see how many inputs it takes
classifier_modules = [type(model.classifier[i]).__name__ for i in range(len(model.classifier))]
First_Linear_Module = classifier_modules.index('Linear')

# Create the classifier for the model 
# Use the transfer models outputs as inputs and the number of image categories as outputs
classifier = Network(model.classifier[First_Linear_Module].in_features, len(train_dataset.classes), 
                     hyperparameters['hidden_layers'], drop_p=hyperparameters['dropout_probability'])

# Attach the classifier to the model
model.classifier = classifier

model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Network(
#     (hidden_layers): ModuleList(
#       (0): Linear(in_features=25088, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=32, bias=True)
#     )
#     (output): Linear(in_features=32, out_features=102, bias=True)
#     (dropout): Dropout(p=0.2)
#   )
# )

# %% [markdown]
# ## Load my checkpoint here (skip if no checkpoint saved):

# %%
# if a model is already saved, load it now
model, accuracy = load_checkpoint('model_checkpoints/checkpoint.pth')

# %% [markdown]
# ## Display the loaded model here:

# %%
# print the model to see what it looks like
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU(inplace)
#     (13): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU(inplace)
#     (15): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (16): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU(inplace)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Network(
#     (hidden_layers): ModuleList(
#       (0): Linear(in_features=25088, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=64, bias=True)
#       (2): Linear(in_features=64, out_features=32, bias=True)
#     )
#     (output): Linear(in_features=32, out_features=102, bias=True)
#     (dropout): Dropout(p=0.2)
#   )
# )

# %% [markdown]
# ## Set the device here:

# %%
# set the device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# print the device to see what it is
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Start evaluating the model here:

# %%
# once the model is loaded into memory, set the criterion and optimizer parameters
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=hyperparameters['learnrate'])

# %%
# check the current model accuracy by doing a forward pass

# Put the model in eval mode and turn off gradients
model.eval()
eval_start = time.time()
with torch.no_grad():
    # Do a validation
    test_loss, accuracy = validation(model, test_dataloader, criterion, device)
eval_time = time.time()-eval_start
# Print the results to the output window
print("Test Loss: {:.3f}.. ".format(test_loss/len(test_dataloader)),
      "Test Accuracy: {:.3f}".format(accuracy/len(test_dataloader)),
      "-- Time: {:>10.3f}".format(eval_time)
     )
# Out:
# Test Loss: 2.398..  Test Accuracy: 0.396 -- Time:     20.420

# %%
# here's a routine to check the feed-forward timing of each processor
for processor in ['cpu', 'cuda']:
    print(processor)
    
    optimizer = optim.Adam(model.classifier.parameters(), lr=hyperparameters['learnrate'])
    model.to(processor)
    
    start = time.time()
    for ii, (inputs, labels) in enumerate(train_dataloader):

        # Move input and label tensors to the GPU
        inputs, labels = inputs.to(processor), labels.to(processor)

        print("Executing forward pass {} ...".format(ii+1))
        outputs = model.forward(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if ii==2:
            break

    total_time = time.time()-start
    print(f"Device = {processor}; Time per batch: {total_time/3:.3f} seconds")
# Out:
# cpu
# Executing forward pass 1 ...
# Executing forward pass 2 ...
# Executing forward pass 3 ...
# Device = cpu; Time per batch: 8.986 seconds
# cuda
# Executing forward pass 1 ...
# Executing forward pass 2 ...
# Executing forward pass 3 ...
# Device = cuda; Time per batch: 0.420 seconds

# %%
# here's a routine to check how many steps the train_dataloader will take
total_steps = ceil(len(train_dataset.samples)/train_dataloader.batch_size)
print(total_steps)
# Out:
# 205

# %% [markdown]
# ## Train the network here:

# %%
# train the network
#with active_session():
model_accuracy = network_train(model, 
                               hyperparameters['epochs'], 
                               hyperparameters['learnrate'],
                               train_dataloader, 
                               test_dataloader, 
                               total_steps,
                               use_GPU=True)
# Out:
# Training network...
# Device = cuda:0
#
# Epoch:  1 / 2 ..  Step:  1 /205.. -- Time:      0.409   (Model is training. Validation after 204 more training steps.)
# Epoch:  1 / 2 ..  Step:  2 /205.. -- Time:      1.186   (Model is training. Validation after 203 more training steps.)
# Epoch:  1 / 2 ..  Step:  3 /205.. -- Time:      1.988   (Model is training. Validation after 202 more training steps.)
# Epoch:  1 / 2 ..  Step:  4 /205.. -- Time:      2.795   (Model is training. Validation after 201 more training steps.)
# Epoch:  1 / 2 ..  Step:  5 /205.. -- Time:      3.595   (Model is training. Validation after 200 more training steps.)
# Epoch:  1 / 2 ..  Step:  6 /205.. -- Time:      4.395   (Model is training. Validation after 199 more training steps.)
# Epoch:  1 / 2 ..  Step:  7 /205.. -- Time:      5.154   (Model is training. Validation after 198 more training steps.)
# Epoch:  1 / 2 ..  Step:  8 /205.. -- Time:      5.946   (Model is training. Validation after 197 more training steps.)
# Epoch:  1 / 2 ..  Step:  9 /205.. -- Time:      6.725   (Model is training. Validation after 196 more training steps.)
# Epoch:  1 / 2 ..  Step: 10 /205.. -- Time:      7.509   (Model is training. Validation after 195 more training steps.)
# Epoch:  1 / 2 ..  Step: 11 /205.. -- Time:      8.266   (Model is training. Validation after 194 more training steps.)
# Epoch:  1 / 2 ..  Step: 12 /205.. -- Time:      9.028   (Model is training. Validation after 193 more training steps.)
# Epoch:  1 / 2 ..  Step: 13 /205.. -- Time:      9.783   (Model is training. Validation after 192 more training steps.)
# Epoch:  1 / 2 ..  Step: 14 /205.. -- Time:     10.541   (Model is training. Validation after 191 more training steps.)
# Epoch:  1 / 2 ..  Step: 15 /205.. -- Time:     11.318   (Model is training. Validation after 190 more training steps.)
# Epoch:  1 / 2 ..  Step: 16 /205.. -- Time:     12.126   (Model is training. Validation after 189 more training steps.)
# Epoch:  1 / 2 ..  Step: 17 /205.. -- Time:     12.903   (Model is training. Validation after 188 more training steps.)
# Epoch:  1 / 2 ..  Step: 18 /205.. -- Time:     13.665   (Model is training. Validation after 187 more training steps.)
# Epoch:  1 / 2 ..  Step: 19 /205.. -- Time:     14.413   (Model is training. Validation after 186 more training steps.)
# Epoch:  1 / 2 ..  Step: 20 /205.. -- Time:     15.160   (Model is training. Validation after 185 more training steps.)
# Epoch:  1 / 2 ..  Step: 21 /205.. -- Time:     15.950   (Model is training. Validation after 184 more training steps.)
# Epoch:  1 / 2 ..  Step: 22 /205.. -- Time:     16.874   (Model is training. Validation after 183 more training steps.)
# Epoch:  1 / 2 ..  Step: 23 /205.. -- Time:     17.665   (Model is training. Validation after 182 more training steps.)
# Epoch:  1 / 2 ..  Step: 24 /205.. -- Time:     18.439   (Model is training. Validation after 181 more training steps.)
# Epoch:  1 / 2 ..  Step: 25 /205.. -- Time:     19.234   (Model is training. Validation after 180 more training steps.)
# Epoch:  1 / 2 ..  Step: 26 /205.. -- Time:     20.033   (Model is training. Validation after 179 more training steps.)
# Epoch:  1 / 2 ..  Step: 27 /205.. -- Time:     20.831   (Model is training. Validation after 178 more training steps.)
# Epoch:  1 / 2 ..  Step: 28 /205.. -- Time:     21.615   (Model is training. Validation after 177 more training steps.)
# Epoch:  1 / 2 ..  Step: 29 /205.. -- Time:     22.424   (Model is training. Validation after 176 more training steps.)
# Epoch:  1 / 2 ..  Step: 30 /205.. -- Time:     23.235   (Model is training. Validation after 175 more training steps.)
# Epoch:  1 / 2 ..  Step: 31 /205.. -- Time:     24.000   (Model is training. Validation after 174 more training steps.)
# Epoch:  1 / 2 ..  Step: 32 /205.. -- Time:     24.784   (Model is training. Validation after 173 more training steps.)
# Epoch:  1 / 2 ..  Step: 33 /205.. -- Time:     25.539   (Model is training. Validation after 172 more training steps.)
# Epoch:  1 / 2 ..  Step: 34 /205.. -- Time:     26.320   (Model is training. Validation after 171 more training steps.)
# Epoch:  1 / 2 ..  Step: 35 /205.. -- Time:     27.099   (Model is training. Validation after 170 more training steps.)
# Epoch:  1 / 2 ..  Step: 36 /205.. -- Time:     27.876   (Model is training. Validation after 169 more training steps.)
# Epoch:  1 / 2 ..  Step: 37 /205.. -- Time:     28.665   (Model is training. Validation after 168 more training steps.)
# Epoch:  1 / 2 ..  Step: 38 /205.. -- Time:     29.401   (Model is training. Validation after 167 more training steps.)
# Epoch:  1 / 2 ..  Step: 39 /205.. -- Time:     30.160   (Model is training. Validation after 166 more training steps.)
# Epoch:  1 / 2 ..  Step: 40 /205.. -- Time:     30.947   (Model is training. Validation after 165 more training steps.)
# Epoch:  1 / 2 ..  Step: 41 /205.. -- Time:     31.722   (Model is training. Validation after 164 more training steps.)
# Epoch:  1 / 2 ..  Step: 42 /205.. -- Time:     32.500   (Model is training. Validation after 163 more training steps.)
# Epoch:  1 / 2 ..  Step: 43 /205.. -- Time:     33.243   (Model is training. Validation after 162 more training steps.)
# Epoch:  1 / 2 ..  Step: 44 /205.. -- Time:     34.038   (Model is training. Validation after 161 more training steps.)
# Epoch:  1 / 2 ..  Step: 45 /205.. -- Time:     34.809   (Model is training. Validation after 160 more training steps.)
# Epoch:  1 / 2 ..  Step: 46 /205.. -- Time:     35.581   (Model is training. Validation after 159 more training steps.)
# Epoch:  1 / 2 ..  Step: 47 /205.. -- Time:     36.348   (Model is training. Validation after 158 more training steps.)
# Epoch:  1 / 2 ..  Step: 48 /205.. -- Time:     37.112   (Model is training. Validation after 157 more training steps.)
# Epoch:  1 / 2 ..  Step: 49 /205.. -- Time:     37.855   (Model is training. Validation after 156 more training steps.)
# Epoch:  1 / 2 ..  Step: 50 /205.. -- Time:     38.632   (Model is training. Validation after 155 more training steps.)
# Epoch:  1 / 2 ..  Step: 51 /205.. -- Time:     39.438   (Model is training. Validation after 154 more training steps.)
# Epoch:  1 / 2 ..  Step: 52 /205.. -- Time:     40.195   (Model is training. Validation after 153 more training steps.)
# Epoch:  1 / 2 ..  Step: 53 /205.. -- Time:     41.003   (Model is training. Validation after 152 more training steps.)
# Epoch:  1 / 2 ..  Step: 54 /205.. -- Time:     41.814   (Model is training. Validation after 151 more training steps.)
# Epoch:  1 / 2 ..  Step: 55 /205.. -- Time:     42.616   (Model is training. Validation after 150 more training steps.)
# Epoch:  1 / 2 ..  Step: 56 /205.. -- Time:     43.374   (Model is training. Validation after 149 more training steps.)
# Epoch:  1 / 2 ..  Step: 57 /205.. -- Time:     44.166   (Model is training. Validation after 148 more training steps.)
# Epoch:  1 / 2 ..  Step: 58 /205.. -- Time:     44.922   (Model is training. Validation after 147 more training steps.)
# Epoch:  1 / 2 ..  Step: 59 /205.. -- Time:     45.691   (Model is training. Validation after 146 more training steps.)
# Epoch:  1 / 2 ..  Step: 60 /205.. -- Time:     46.464   (Model is training. Validation after 145 more training steps.)
# Epoch:  1 / 2 ..  Step: 61 /205.. -- Time:     47.270   (Model is training. Validation after 144 more training steps.)
# Epoch:  1 / 2 ..  Step: 62 /205.. -- Time:     48.069   (Model is training. Validation after 143 more training steps.)
# Epoch:  1 / 2 ..  Step: 63 /205.. -- Time:     48.838   (Model is training. Validation after 142 more training steps.)
# Epoch:  1 / 2 ..  Step: 64 /205.. -- Time:     49.651   (Model is training. Validation after 141 more training steps.)
# Epoch:  1 / 2 ..  Step: 65 /205.. -- Time:     50.400   (Model is training. Validation after 140 more training steps.)
# Epoch:  1 / 2 ..  Step: 66 /205.. -- Time:     51.153   (Model is training. Validation after 139 more training steps.)
# Epoch:  1 / 2 ..  Step: 67 /205.. -- Time:     51.948   (Model is training. Validation after 138 more training steps.)
# Epoch:  1 / 2 ..  Step: 68 /205.. -- Time:     52.695   (Model is training. Validation after 137 more training steps.)
# Epoch:  1 / 2 ..  Step: 69 /205.. -- Time:     53.467   (Model is training. Validation after 136 more training steps.)
# Epoch:  1 / 2 ..  Step: 70 /205.. -- Time:     54.213   (Model is training. Validation after 135 more training steps.)
# Epoch:  1 / 2 ..  Step: 71 /205.. -- Time:     55.001   (Model is training. Validation after 134 more training steps.)
# Epoch:  1 / 2 ..  Step: 72 /205.. -- Time:     55.784   (Model is training. Validation after 133 more training steps.)
# Epoch:  1 / 2 ..  Step: 73 /205.. -- Time:     56.562   (Model is training. Validation after 132 more training steps.)
# Epoch:  1 / 2 ..  Step: 74 /205.. -- Time:     57.329   (Model is training. Validation after 131 more training steps.)
# Epoch:  1 / 2 ..  Step: 75 /205.. -- Time:     58.117   (Model is training. Validation after 130 more training steps.)
# Epoch:  1 / 2 ..  Step: 76 /205.. -- Time:     58.995   (Model is training. Validation after 129 more training steps.)
# Epoch:  1 / 2 ..  Step: 77 /205.. -- Time:     59.763   (Model is training. Validation after 128 more training steps.)
# Epoch:  1 / 2 ..  Step: 78 /205.. -- Time:     60.521   (Model is training. Validation after 127 more training steps.)
# Epoch:  1 / 2 ..  Step: 79 /205.. -- Time:     61.282   (Model is training. Validation after 126 more training steps.)
# Epoch:  1 / 2 ..  Step: 80 /205.. -- Time:     62.056   (Model is training. Validation after 125 more training steps.)
# Epoch:  1 / 2 ..  Step: 81 /205.. -- Time:     62.826   (Model is training. Validation after 124 more training steps.)
# Epoch:  1 / 2 ..  Step: 82 /205.. -- Time:     63.609   (Model is training. Validation after 123 more training steps.)
# Epoch:  1 / 2 ..  Step: 83 /205.. -- Time:     64.408   (Model is training. Validation after 122 more training steps.)
# Epoch:  1 / 2 ..  Step: 84 /205.. -- Time:     65.196   (Model is training. Validation after 121 more training steps.)
# Epoch:  1 / 2 ..  Step: 85 /205.. -- Time:     65.954   (Model is training. Validation after 120 more training steps.)
# Epoch:  1 / 2 ..  Step: 86 /205.. -- Time:     66.734   (Model is training. Validation after 119 more training steps.)
# Epoch:  1 / 2 ..  Step: 87 /205.. -- Time:     67.498   (Model is training. Validation after 118 more training steps.)
# Epoch:  1 / 2 ..  Step: 88 /205.. -- Time:     68.282   (Model is training. Validation after 117 more training steps.)
# Epoch:  1 / 2 ..  Step: 89 /205.. -- Time:     69.081   (Model is training. Validation after 116 more training steps.)
# Epoch:  1 / 2 ..  Step: 90 /205.. -- Time:     69.904   (Model is training. Validation after 115 more training steps.)
# Epoch:  1 / 2 ..  Step: 91 /205.. -- Time:     70.695   (Model is training. Validation after 114 more training steps.)
# Epoch:  1 / 2 ..  Step: 92 /205.. -- Time:     71.487   (Model is training. Validation after 113 more training steps.)
# Epoch:  1 / 2 ..  Step: 93 /205.. -- Time:     72.256   (Model is training. Validation after 112 more training steps.)
# Epoch:  1 / 2 ..  Step: 94 /205.. -- Time:     73.069   (Model is training. Validation after 111 more training steps.)
# Epoch:  1 / 2 ..  Step: 95 /205.. -- Time:     73.875   (Model is training. Validation after 110 more training steps.)
# Epoch:  1 / 2 ..  Step: 96 /205.. -- Time:     74.644   (Model is training. Validation after 109 more training steps.)
# Epoch:  1 / 2 ..  Step: 97 /205.. -- Time:     75.414   (Model is training. Validation after 108 more training steps.)
# Epoch:  1 / 2 ..  Step: 98 /205.. -- Time:     76.191   (Model is training. Validation after 107 more training steps.)
# Epoch:  1 / 2 ..  Step: 99 /205.. -- Time:     76.972   (Model is training. Validation after 106 more training steps.)
# Epoch:  1 / 2 ..  Step: 100/205.. -- Time:     77.803   (Model is training. Validation after 105 more training steps.)
# Epoch:  1 / 2 ..  Step: 101/205.. -- Time:     78.587   (Model is training. Validation after 104 more training steps.)
# Epoch:  1 / 2 ..  Step: 102/205.. -- Time:     79.356   (Model is training. Validation after 103 more training steps.)
# Epoch:  1 / 2 ..  Step: 103/205.. -- Time:     80.145   (Model is training. Validation after 102 more training steps.)
# Epoch:  1 / 2 ..  Step: 104/205.. -- Time:     80.988   (Model is training. Validation after 101 more training steps.)
# Epoch:  1 / 2 ..  Step: 105/205.. -- Time:     81.773   (Model is training. Validation after 100 more training steps.)
# Epoch:  1 / 2 ..  Step: 106/205.. -- Time:     82.571   (Model is training. Validation after 99 more training steps.)
# Epoch:  1 / 2 ..  Step: 107/205.. -- Time:     83.357   (Model is training. Validation after 98 more training steps.)
# Epoch:  1 / 2 ..  Step: 108/205.. -- Time:     84.163   (Model is training. Validation after 97 more training steps.)
# Epoch:  1 / 2 ..  Step: 109/205.. -- Time:     84.976   (Model is training. Validation after 96 more training steps.)
# Epoch:  1 / 2 ..  Step: 110/205.. -- Time:     85.780   (Model is training. Validation after 95 more training steps.)
# Epoch:  1 / 2 ..  Step: 111/205.. -- Time:     86.639   (Model is training. Validation after 94 more training steps.)
# Epoch:  1 / 2 ..  Step: 112/205.. -- Time:     87.423   (Model is training. Validation after 93 more training steps.)
# Epoch:  1 / 2 ..  Step: 113/205.. -- Time:     88.226   (Model is training. Validation after 92 more training steps.)
# Epoch:  1 / 2 ..  Step: 114/205.. -- Time:     88.998   (Model is training. Validation after 91 more training steps.)
# Epoch:  1 / 2 ..  Step: 115/205.. -- Time:     89.846   (Model is training. Validation after 90 more training steps.)
# Epoch:  1 / 2 ..  Step: 116/205.. -- Time:     90.671   (Model is training. Validation after 89 more training steps.)
# Epoch:  1 / 2 ..  Step: 117/205.. -- Time:     91.526   (Model is training. Validation after 88 more training steps.)
# Epoch:  1 / 2 ..  Step: 118/205.. -- Time:     92.364   (Model is training. Validation after 87 more training steps.)
# Epoch:  1 / 2 ..  Step: 119/205.. -- Time:     93.152   (Model is training. Validation after 86 more training steps.)
# Epoch:  1 / 2 ..  Step: 120/205.. -- Time:     93.966   (Model is training. Validation after 85 more training steps.)
# Epoch:  1 / 2 ..  Step: 121/205.. -- Time:     94.770   (Model is training. Validation after 84 more training steps.)
# Epoch:  1 / 2 ..  Step: 122/205.. -- Time:     95.594   (Model is training. Validation after 83 more training steps.)
# Epoch:  1 / 2 ..  Step: 123/205.. -- Time:     96.434   (Model is training. Validation after 82 more training steps.)
# Epoch:  1 / 2 ..  Step: 124/205.. -- Time:     97.231   (Model is training. Validation after 81 more training steps.)
# Epoch:  1 / 2 ..  Step: 125/205.. -- Time:     98.077   (Model is training. Validation after 80 more training steps.)
# Epoch:  1 / 2 ..  Step: 126/205.. -- Time:     98.910   (Model is training. Validation after 79 more training steps.)
# Epoch:  1 / 2 ..  Step: 127/205.. -- Time:     99.714   (Model is training. Validation after 78 more training steps.)
# Epoch:  1 / 2 ..  Step: 128/205.. -- Time:    100.556   (Model is training. Validation after 77 more training steps.)
# Epoch:  1 / 2 ..  Step: 129/205.. -- Time:    101.398   (Model is training. Validation after 76 more training steps.)
# Epoch:  1 / 2 ..  Step: 130/205.. -- Time:    102.225   (Model is training. Validation after 75 more training steps.)
# Epoch:  1 / 2 ..  Step: 131/205.. -- Time:    103.048   (Model is training. Validation after 74 more training steps.)
# Epoch:  1 / 2 ..  Step: 132/205.. -- Time:    103.851   (Model is training. Validation after 73 more training steps.)
# Epoch:  1 / 2 ..  Step: 133/205.. -- Time:    104.667   (Model is training. Validation after 72 more training steps.)
# Epoch:  1 / 2 ..  Step: 134/205.. -- Time:    105.468   (Model is training. Validation after 71 more training steps.)
# Epoch:  1 / 2 ..  Step: 135/205.. -- Time:    106.268   (Model is training. Validation after 70 more training steps.)
# Epoch:  1 / 2 ..  Step: 136/205.. -- Time:    107.107   (Model is training. Validation after 69 more training steps.)
# Epoch:  1 / 2 ..  Step: 137/205.. -- Time:    107.857   (Model is training. Validation after 68 more training steps.)
# Epoch:  1 / 2 ..  Step: 138/205.. -- Time:    108.689   (Model is training. Validation after 67 more training steps.)
# Epoch:  1 / 2 ..  Step: 139/205.. -- Time:    109.496   (Model is training. Validation after 66 more training steps.)
# Epoch:  1 / 2 ..  Step: 140/205.. -- Time:    110.305   (Model is training. Validation after 65 more training steps.)
# Epoch:  1 / 2 ..  Step: 141/205.. -- Time:    111.116   (Model is training. Validation after 64 more training steps.)
# Epoch:  1 / 2 ..  Step: 142/205.. -- Time:    111.940   (Model is training. Validation after 63 more training steps.)
# Epoch:  1 / 2 ..  Step: 143/205.. -- Time:    112.749   (Model is training. Validation after 62 more training steps.)
# Epoch:  1 / 2 ..  Step: 144/205.. -- Time:    113.629   (Model is training. Validation after 61 more training steps.)
# Epoch:  1 / 2 ..  Step: 145/205.. -- Time:    114.462   (Model is training. Validation after 60 more training steps.)
# Epoch:  1 / 2 ..  Step: 146/205.. -- Time:    115.248   (Model is training. Validation after 59 more training steps.)
# Epoch:  1 / 2 ..  Step: 147/205.. -- Time:    116.050   (Model is training. Validation after 58 more training steps.)
# Epoch:  1 / 2 ..  Step: 148/205.. -- Time:    116.849   (Model is training. Validation after 57 more training steps.)
# Epoch:  1 / 2 ..  Step: 149/205.. -- Time:    117.646   (Model is training. Validation after 56 more training steps.)
# Epoch:  1 / 2 ..  Step: 150/205.. -- Time:    118.463   (Model is training. Validation after 55 more training steps.)
# Epoch:  1 / 2 ..  Step: 151/205.. -- Time:    119.265   (Model is training. Validation after 54 more training steps.)
# Epoch:  1 / 2 ..  Step: 152/205.. -- Time:    120.172   (Model is training. Validation after 53 more training steps.)
# Epoch:  1 / 2 ..  Step: 153/205.. -- Time:    121.003   (Model is training. Validation after 52 more training steps.)
# Epoch:  1 / 2 ..  Step: 154/205.. -- Time:    121.855   (Model is training. Validation after 51 more training steps.)
# Epoch:  1 / 2 ..  Step: 155/205.. -- Time:    122.709   (Model is training. Validation after 50 more training steps.)
# Epoch:  1 / 2 ..  Step: 156/205.. -- Time:    123.528   (Model is training. Validation after 49 more training steps.)
# Epoch:  1 / 2 ..  Step: 157/205.. -- Time:    124.359   (Model is training. Validation after 48 more training steps.)
# Epoch:  1 / 2 ..  Step: 158/205.. -- Time:    125.154   (Model is training. Validation after 47 more training steps.)
# Epoch:  1 / 2 ..  Step: 159/205.. -- Time:    125.950   (Model is training. Validation after 46 more training steps.)
# Epoch:  1 / 2 ..  Step: 160/205.. -- Time:    126.758   (Model is training. Validation after 45 more training steps.)
# Epoch:  1 / 2 ..  Step: 161/205.. -- Time:    127.564   (Model is training. Validation after 44 more training steps.)
# Epoch:  1 / 2 ..  Step: 162/205.. -- Time:    128.392   (Model is training. Validation after 43 more training steps.)
# Epoch:  1 / 2 ..  Step: 163/205.. -- Time:    129.191   (Model is training. Validation after 42 more training steps.)
# Epoch:  1 / 2 ..  Step: 164/205.. -- Time:    130.016   (Model is training. Validation after 41 more training steps.)
# Epoch:  1 / 2 ..  Step: 165/205.. -- Time:    130.795   (Model is training. Validation after 40 more training steps.)
# Epoch:  1 / 2 ..  Step: 166/205.. -- Time:    131.656   (Model is training. Validation after 39 more training steps.)
# Epoch:  1 / 2 ..  Step: 167/205.. -- Time:    132.495   (Model is training. Validation after 38 more training steps.)
# Epoch:  1 / 2 ..  Step: 168/205.. -- Time:    133.332   (Model is training. Validation after 37 more training steps.)
# Epoch:  1 / 2 ..  Step: 169/205.. -- Time:    134.182   (Model is training. Validation after 36 more training steps.)
# Epoch:  1 / 2 ..  Step: 170/205.. -- Time:    134.994   (Model is training. Validation after 35 more training steps.)
# Epoch:  1 / 2 ..  Step: 171/205.. -- Time:    135.811   (Model is training. Validation after 34 more training steps.)
# Epoch:  1 / 2 ..  Step: 172/205.. -- Time:    136.701   (Model is training. Validation after 33 more training steps.)
# Epoch:  1 / 2 ..  Step: 173/205.. -- Time:    137.473   (Model is training. Validation after 32 more training steps.)
# Epoch:  1 / 2 ..  Step: 174/205.. -- Time:    138.321   (Model is training. Validation after 31 more training steps.)
# Epoch:  1 / 2 ..  Step: 175/205.. -- Time:    139.204   (Model is training. Validation after 30 more training steps.)
# Epoch:  1 / 2 ..  Step: 176/205.. -- Time:    140.039   (Model is training. Validation after 29 more training steps.)
# Epoch:  1 / 2 ..  Step: 177/205.. -- Time:    140.842   (Model is training. Validation after 28 more training steps.)
# Epoch:  1 / 2 ..  Step: 178/205.. -- Time:    141.634   (Model is training. Validation after 27 more training steps.)
# Epoch:  1 / 2 ..  Step: 179/205.. -- Time:    142.458   (Model is training. Validation after 26 more training steps.)
# Epoch:  1 / 2 ..  Step: 180/205.. -- Time:    143.255   (Model is training. Validation after 25 more training steps.)
# Epoch:  1 / 2 ..  Step: 181/205.. -- Time:    144.057   (Model is training. Validation after 24 more training steps.)
# Epoch:  1 / 2 ..  Step: 182/205.. -- Time:    144.895   (Model is training. Validation after 23 more training steps.)
# Epoch:  1 / 2 ..  Step: 183/205.. -- Time:    145.687   (Model is training. Validation after 22 more training steps.)
# Epoch:  1 / 2 ..  Step: 184/205.. -- Time:    146.558   (Model is training. Validation after 21 more training steps.)
# Epoch:  1 / 2 ..  Step: 185/205.. -- Time:    147.386   (Model is training. Validation after 20 more training steps.)
# Epoch:  1 / 2 ..  Step: 186/205.. -- Time:    148.205   (Model is training. Validation after 19 more training steps.)
# Epoch:  1 / 2 ..  Step: 187/205.. -- Time:    149.040   (Model is training. Validation after 18 more training steps.)
# Epoch:  1 / 2 ..  Step: 188/205.. -- Time:    149.854   (Model is training. Validation after 17 more training steps.)
# Epoch:  1 / 2 ..  Step: 189/205.. -- Time:    150.663   (Model is training. Validation after 16 more training steps.)
# Epoch:  1 / 2 ..  Step: 190/205.. -- Time:    151.446   (Model is training. Validation after 15 more training steps.)
# Epoch:  1 / 2 ..  Step: 191/205.. -- Time:    152.305   (Model is training. Validation after 14 more training steps.)
# Epoch:  1 / 2 ..  Step: 192/205.. -- Time:    153.137   (Model is training. Validation after 13 more training steps.)
# Epoch:  1 / 2 ..  Step: 193/205.. -- Time:    153.956   (Model is training. Validation after 12 more training steps.)
# Epoch:  1 / 2 ..  Step: 194/205.. -- Time:    154.748   (Model is training. Validation after 11 more training steps.)
# Epoch:  1 / 2 ..  Step: 195/205.. -- Time:    155.576   (Model is training. Validation after 10 more training steps.)
# Epoch:  1 / 2 ..  Step: 196/205.. -- Time:    156.432   (Model is training. Validation after 9 more training steps.)
# Epoch:  1 / 2 ..  Step: 197/205.. -- Time:    157.268   (Model is training. Validation after 8 more training steps.)
# Epoch:  1 / 2 ..  Step: 198/205.. -- Time:    158.112   (Model is training. Validation after 7 more training steps.)
# Epoch:  1 / 2 ..  Step: 199/205.. -- Time:    158.926   (Model is training. Validation after 6 more training steps.)
# Epoch:  1 / 2 ..  Step: 200/205.. -- Time:    159.764   (Model is training. Validation after 5 more training steps.)
# Epoch:  1 / 2 ..  Step: 201/205.. -- Time:    160.553   (Model is training. Validation after 4 more training steps.)
# Epoch:  1 / 2 ..  Step: 202/205.. -- Time:    161.363   (Model is training. Validation after 3 more training steps.)
# Epoch:  1 / 2 ..  Step: 203/205.. -- Time:    162.150   (Model is training. Validation after 2 more training steps.)
# Epoch:  1 / 2 ..  Step: 204/205.. -- Time:    162.987   (Model is training. Validation after 1 more training steps.)
# Epoch:  1 / 2 ..  Step: 205/205.. -- Time:    163.679   (Model is training. Validation after 0 more training steps.)
# Epoch:  1 / 2 ..  Step: 205/205.. -- Time:    184.123 Training Loss: 2.811..  Test Loss: 1.967..  Test Accuracy: 0.494
# Epoch:  2 / 2 ..  Step:  1 /205.. -- Time:    184.547   (Model is training. Validation after 204 more training steps.)
# Epoch:  2 / 2 ..  Step:  2 /205.. -- Time:    185.318   (Model is training. Validation after 203 more training steps.)
# Epoch:  2 / 2 ..  Step:  3 /205.. -- Time:    186.135   (Model is training. Validation after 202 more training steps.)
# Epoch:  2 / 2 ..  Step:  4 /205.. -- Time:    186.958   (Model is training. Validation after 201 more training steps.)
# Epoch:  2 / 2 ..  Step:  5 /205.. -- Time:    187.783   (Model is training. Validation after 200 more training steps.)
# Epoch:  2 / 2 ..  Step:  6 /205.. -- Time:    188.572   (Model is training. Validation after 199 more training steps.)
# Epoch:  2 / 2 ..  Step:  7 /205.. -- Time:    189.365   (Model is training. Validation after 198 more training steps.)
# Epoch:  2 / 2 ..  Step:  8 /205.. -- Time:    190.186   (Model is training. Validation after 197 more training steps.)
# Epoch:  2 / 2 ..  Step:  9 /205.. -- Time:    191.005   (Model is training. Validation after 196 more training steps.)
# Epoch:  2 / 2 ..  Step: 10 /205.. -- Time:    191.855   (Model is training. Validation after 195 more training steps.)
# Epoch:  2 / 2 ..  Step: 11 /205.. -- Time:    192.667   (Model is training. Validation after 194 more training steps.)
# Epoch:  2 / 2 ..  Step: 12 /205.. -- Time:    193.503   (Model is training. Validation after 193 more training steps.)
# Epoch:  2 / 2 ..  Step: 13 /205.. -- Time:    194.345   (Model is training. Validation after 192 more training steps.)
# Epoch:  2 / 2 ..  Step: 14 /205.. -- Time:    195.144   (Model is training. Validation after 191 more training steps.)
# Epoch:  2 / 2 ..  Step: 15 /205.. -- Time:    195.928   (Model is training. Validation after 190 more training steps.)
# Epoch:  2 / 2 ..  Step: 16 /205.. -- Time:    196.728   (Model is training. Validation after 189 more training steps.)
# Epoch:  2 / 2 ..  Step: 17 /205.. -- Time:    197.520   (Model is training. Validation after 188 more training steps.)
# Epoch:  2 / 2 ..  Step: 18 /205.. -- Time:    198.325   (Model is training. Validation after 187 more training steps.)
# Epoch:  2 / 2 ..  Step: 19 /205.. -- Time:    199.121   (Model is training. Validation after 186 more training steps.)
# Epoch:  2 / 2 ..  Step: 20 /205.. -- Time:    199.923   (Model is training. Validation after 185 more training steps.)
# Epoch:  2 / 2 ..  Step: 21 /205.. -- Time:    200.698   (Model is training. Validation after 184 more training steps.)
# Epoch:  2 / 2 ..  Step: 22 /205.. -- Time:    201.486   (Model is training. Validation after 183 more training steps.)
# Epoch:  2 / 2 ..  Step: 23 /205.. -- Time:    202.269   (Model is training. Validation after 182 more training steps.)
# Epoch:  2 / 2 ..  Step: 24 /205.. -- Time:    203.066   (Model is training. Validation after 181 more training steps.)
# Epoch:  2 / 2 ..  Step: 25 /205.. -- Time:    203.852   (Model is training. Validation after 180 more training steps.)
# Epoch:  2 / 2 ..  Step: 26 /205.. -- Time:    204.639   (Model is training. Validation after 179 more training steps.)
# Epoch:  2 / 2 ..  Step: 27 /205.. -- Time:    205.406   (Model is training. Validation after 178 more training steps.)
# Epoch:  2 / 2 ..  Step: 28 /205.. -- Time:    206.194   (Model is training. Validation after 177 more training steps.)
# Epoch:  2 / 2 ..  Step: 29 /205.. -- Time:    206.996   (Model is training. Validation after 176 more training steps.)
# Epoch:  2 / 2 ..  Step: 30 /205.. -- Time:    207.825   (Model is training. Validation after 175 more training steps.)
# Epoch:  2 / 2 ..  Step: 31 /205.. -- Time:    208.578   (Model is training. Validation after 174 more training steps.)
# Epoch:  2 / 2 ..  Step: 32 /205.. -- Time:    209.342   (Model is training. Validation after 173 more training steps.)
# Epoch:  2 / 2 ..  Step: 33 /205.. -- Time:    210.114   (Model is training. Validation after 172 more training steps.)
# Epoch:  2 / 2 ..  Step: 34 /205.. -- Time:    210.985   (Model is training. Validation after 171 more training steps.)
# Epoch:  2 / 2 ..  Step: 35 /205.. -- Time:    211.789   (Model is training. Validation after 170 more training steps.)
# Epoch:  2 / 2 ..  Step: 36 /205.. -- Time:    212.574   (Model is training. Validation after 169 more training steps.)
# Epoch:  2 / 2 ..  Step: 37 /205.. -- Time:    213.302   (Model is training. Validation after 168 more training steps.)
# Epoch:  2 / 2 ..  Step: 38 /205.. -- Time:    214.079   (Model is training. Validation after 167 more training steps.)
# Epoch:  2 / 2 ..  Step: 39 /205.. -- Time:    214.872   (Model is training. Validation after 166 more training steps.)
# Epoch:  2 / 2 ..  Step: 40 /205.. -- Time:    215.703   (Model is training. Validation after 165 more training steps.)
# Epoch:  2 / 2 ..  Step: 41 /205.. -- Time:    216.476   (Model is training. Validation after 164 more training steps.)
# Epoch:  2 / 2 ..  Step: 42 /205.. -- Time:    217.280   (Model is training. Validation after 163 more training steps.)
# Epoch:  2 / 2 ..  Step: 43 /205.. -- Time:    218.103   (Model is training. Validation after 162 more training steps.)
# Epoch:  2 / 2 ..  Step: 44 /205.. -- Time:    218.881   (Model is training. Validation after 161 more training steps.)
# Epoch:  2 / 2 ..  Step: 45 /205.. -- Time:    219.637   (Model is training. Validation after 160 more training steps.)
# Epoch:  2 / 2 ..  Step: 46 /205.. -- Time:    220.406   (Model is training. Validation after 159 more training steps.)
# Epoch:  2 / 2 ..  Step: 47 /205.. -- Time:    221.234   (Model is training. Validation after 158 more training steps.)
# Epoch:  2 / 2 ..  Step: 48 /205.. -- Time:    222.010   (Model is training. Validation after 157 more training steps.)
# Epoch:  2 / 2 ..  Step: 49 /205.. -- Time:    222.797   (Model is training. Validation after 156 more training steps.)
# Epoch:  2 / 2 ..  Step: 50 /205.. -- Time:    223.582   (Model is training. Validation after 155 more training steps.)
# Epoch:  2 / 2 ..  Step: 51 /205.. -- Time:    224.333   (Model is training. Validation after 154 more training steps.)
# Epoch:  2 / 2 ..  Step: 52 /205.. -- Time:    225.138   (Model is training. Validation after 153 more training steps.)
# Epoch:  2 / 2 ..  Step: 53 /205.. -- Time:    225.946   (Model is training. Validation after 152 more training steps.)
# Epoch:  2 / 2 ..  Step: 54 /205.. -- Time:    226.731   (Model is training. Validation after 151 more training steps.)
# Epoch:  2 / 2 ..  Step: 55 /205.. -- Time:    227.550   (Model is training. Validation after 150 more training steps.)
# Epoch:  2 / 2 ..  Step: 56 /205.. -- Time:    228.373   (Model is training. Validation after 149 more training steps.)
# Epoch:  2 / 2 ..  Step: 57 /205.. -- Time:    229.139   (Model is training. Validation after 148 more training steps.)
# Epoch:  2 / 2 ..  Step: 58 /205.. -- Time:    229.927   (Model is training. Validation after 147 more training steps.)
# Epoch:  2 / 2 ..  Step: 59 /205.. -- Time:    230.658   (Model is training. Validation after 146 more training steps.)
# Epoch:  2 / 2 ..  Step: 60 /205.. -- Time:    231.447   (Model is training. Validation after 145 more training steps.)
# Epoch:  2 / 2 ..  Step: 61 /205.. -- Time:    232.211   (Model is training. Validation after 144 more training steps.)
# Epoch:  2 / 2 ..  Step: 62 /205.. -- Time:    233.011   (Model is training. Validation after 143 more training steps.)
# Epoch:  2 / 2 ..  Step: 63 /205.. -- Time:    233.808   (Model is training. Validation after 142 more training steps.)
# Epoch:  2 / 2 ..  Step: 64 /205.. -- Time:    234.555   (Model is training. Validation after 141 more training steps.)
# Epoch:  2 / 2 ..  Step: 65 /205.. -- Time:    235.330   (Model is training. Validation after 140 more training steps.)
# Epoch:  2 / 2 ..  Step: 66 /205.. -- Time:    236.111   (Model is training. Validation after 139 more training steps.)
# Epoch:  2 / 2 ..  Step: 67 /205.. -- Time:    236.874   (Model is training. Validation after 138 more training steps.)
# Epoch:  2 / 2 ..  Step: 68 /205.. -- Time:    237.675   (Model is training. Validation after 137 more training steps.)
# Epoch:  2 / 2 ..  Step: 69 /205.. -- Time:    238.453   (Model is training. Validation after 136 more training steps.)
# Epoch:  2 / 2 ..  Step: 70 /205.. -- Time:    239.233   (Model is training. Validation after 135 more training steps.)
# Epoch:  2 / 2 ..  Step: 71 /205.. -- Time:    240.001   (Model is training. Validation after 134 more training steps.)
# Epoch:  2 / 2 ..  Step: 72 /205.. -- Time:    240.747   (Model is training. Validation after 133 more training steps.)
# Epoch:  2 / 2 ..  Step: 73 /205.. -- Time:    241.545   (Model is training. Validation after 132 more training steps.)
# Epoch:  2 / 2 ..  Step: 74 /205.. -- Time:    242.419   (Model is training. Validation after 131 more training steps.)
# Epoch:  2 / 2 ..  Step: 75 /205.. -- Time:    243.201   (Model is training. Validation after 130 more training steps.)
# Epoch:  2 / 2 ..  Step: 76 /205.. -- Time:    243.941   (Model is training. Validation after 129 more training steps.)
# Epoch:  2 / 2 ..  Step: 77 /205.. -- Time:    244.738   (Model is training. Validation after 128 more training steps.)
# Epoch:  2 / 2 ..  Step: 78 /205.. -- Time:    245.512   (Model is training. Validation after 127 more training steps.)
# Epoch:  2 / 2 ..  Step: 79 /205.. -- Time:    246.306   (Model is training. Validation after 126 more training steps.)
# Epoch:  2 / 2 ..  Step: 80 /205.. -- Time:    247.114   (Model is training. Validation after 125 more training steps.)
# Epoch:  2 / 2 ..  Step: 81 /205.. -- Time:    247.868   (Model is training. Validation after 124 more training steps.)
# Epoch:  2 / 2 ..  Step: 82 /205.. -- Time:    248.683   (Model is training. Validation after 123 more training steps.)
# Epoch:  2 / 2 ..  Step: 83 /205.. -- Time:    249.483   (Model is training. Validation after 122 more training steps.)
# Epoch:  2 / 2 ..  Step: 84 /205.. -- Time:    250.283   (Model is training. Validation after 121 more training steps.)
# Epoch:  2 / 2 ..  Step: 85 /205.. -- Time:    251.125   (Model is training. Validation after 120 more training steps.)
# Epoch:  2 / 2 ..  Step: 86 /205.. -- Time:    251.935   (Model is training. Validation after 119 more training steps.)
# Epoch:  2 / 2 ..  Step: 87 /205.. -- Time:    252.747   (Model is training. Validation after 118 more training steps.)
# Epoch:  2 / 2 ..  Step: 88 /205.. -- Time:    253.563   (Model is training. Validation after 117 more training steps.)
# Epoch:  2 / 2 ..  Step: 89 /205.. -- Time:    254.337   (Model is training. Validation after 116 more training steps.)
# Epoch:  2 / 2 ..  Step: 90 /205.. -- Time:    255.121   (Model is training. Validation after 115 more training steps.)
# Epoch:  2 / 2 ..  Step: 91 /205.. -- Time:    255.916   (Model is training. Validation after 114 more training steps.)
# Epoch:  2 / 2 ..  Step: 92 /205.. -- Time:    256.748   (Model is training. Validation after 113 more training steps.)
# Epoch:  2 / 2 ..  Step: 93 /205.. -- Time:    257.497   (Model is training. Validation after 112 more training steps.)
# Epoch:  2 / 2 ..  Step: 94 /205.. -- Time:    258.277   (Model is training. Validation after 111 more training steps.)
# Epoch:  2 / 2 ..  Step: 95 /205.. -- Time:    259.060   (Model is training. Validation after 110 more training steps.)
# Epoch:  2 / 2 ..  Step: 96 /205.. -- Time:    259.875   (Model is training. Validation after 109 more training steps.)
# Epoch:  2 / 2 ..  Step: 97 /205.. -- Time:    260.652   (Model is training. Validation after 108 more training steps.)
# Epoch:  2 / 2 ..  Step: 98 /205.. -- Time:    261.432   (Model is training. Validation after 107 more training steps.)
# Epoch:  2 / 2 ..  Step: 99 /205.. -- Time:    262.180   (Model is training. Validation after 106 more training steps.)
# Epoch:  2 / 2 ..  Step: 100/205.. -- Time:    262.963   (Model is training. Validation after 105 more training steps.)
# Epoch:  2 / 2 ..  Step: 101/205.. -- Time:    263.816   (Model is training. Validation after 104 more training steps.)
# Epoch:  2 / 2 ..  Step: 102/205.. -- Time:    264.637   (Model is training. Validation after 103 more training steps.)
# Epoch:  2 / 2 ..  Step: 103/205.. -- Time:    265.424   (Model is training. Validation after 102 more training steps.)
# Epoch:  2 / 2 ..  Step: 104/205.. -- Time:    266.229   (Model is training. Validation after 101 more training steps.)
# Epoch:  2 / 2 ..  Step: 105/205.. -- Time:    267.007   (Model is training. Validation after 100 more training steps.)
# Epoch:  2 / 2 ..  Step: 106/205.. -- Time:    267.822   (Model is training. Validation after 99 more training steps.)
# Epoch:  2 / 2 ..  Step: 107/205.. -- Time:    268.617   (Model is training. Validation after 98 more training steps.)
# Epoch:  2 / 2 ..  Step: 108/205.. -- Time:    269.419   (Model is training. Validation after 97 more training steps.)
# Epoch:  2 / 2 ..  Step: 109/205.. -- Time:    270.213   (Model is training. Validation after 96 more training steps.)
# Epoch:  2 / 2 ..  Step: 110/205.. -- Time:    271.008   (Model is training. Validation after 95 more training steps.)
# Epoch:  2 / 2 ..  Step: 111/205.. -- Time:    271.829   (Model is training. Validation after 94 more training steps.)
# Epoch:  2 / 2 ..  Step: 112/205.. -- Time:    272.628   (Model is training. Validation after 93 more training steps.)
# Epoch:  2 / 2 ..  Step: 113/205.. -- Time:    273.437   (Model is training. Validation after 92 more training steps.)
# Epoch:  2 / 2 ..  Step: 114/205.. -- Time:    274.230   (Model is training. Validation after 91 more training steps.)
# Epoch:  2 / 2 ..  Step: 115/205.. -- Time:    275.017   (Model is training. Validation after 90 more training steps.)
# Epoch:  2 / 2 ..  Step: 116/205.. -- Time:    275.795   (Model is training. Validation after 89 more training steps.)
# Epoch:  2 / 2 ..  Step: 117/205.. -- Time:    276.590   (Model is training. Validation after 88 more training steps.)
# Epoch:  2 / 2 ..  Step: 118/205.. -- Time:    277.366   (Model is training. Validation after 87 more training steps.)
# Epoch:  2 / 2 ..  Step: 119/205.. -- Time:    278.161   (Model is training. Validation after 86 more training steps.)
# Epoch:  2 / 2 ..  Step: 120/205.. -- Time:    278.928   (Model is training. Validation after 85 more training steps.)
# Epoch:  2 / 2 ..  Step: 121/205.. -- Time:    279.731   (Model is training. Validation after 84 more training steps.)
# Epoch:  2 / 2 ..  Step: 122/205.. -- Time:    280.536   (Model is training. Validation after 83 more training steps.)
# Epoch:  2 / 2 ..  Step: 123/205.. -- Time:    281.337   (Model is training. Validation after 82 more training steps.)
# Epoch:  2 / 2 ..  Step: 124/205.. -- Time:    282.136   (Model is training. Validation after 81 more training steps.)
# Epoch:  2 / 2 ..  Step: 125/205.. -- Time:    282.976   (Model is training. Validation after 80 more training steps.)
# Epoch:  2 / 2 ..  Step: 126/205.. -- Time:    283.750   (Model is training. Validation after 79 more training steps.)
# Epoch:  2 / 2 ..  Step: 127/205.. -- Time:    284.582   (Model is training. Validation after 78 more training steps.)
# Epoch:  2 / 2 ..  Step: 128/205.. -- Time:    285.352   (Model is training. Validation after 77 more training steps.)
# Epoch:  2 / 2 ..  Step: 129/205.. -- Time:    286.105   (Model is training. Validation after 76 more training steps.)
# Epoch:  2 / 2 ..  Step: 130/205.. -- Time:    286.900   (Model is training. Validation after 75 more training steps.)
# Epoch:  2 / 2 ..  Step: 131/205.. -- Time:    287.707   (Model is training. Validation after 74 more training steps.)
# Epoch:  2 / 2 ..  Step: 132/205.. -- Time:    288.483   (Model is training. Validation after 73 more training steps.)
# Epoch:  2 / 2 ..  Step: 133/205.. -- Time:    289.266   (Model is training. Validation after 72 more training steps.)
# Epoch:  2 / 2 ..  Step: 134/205.. -- Time:    290.078   (Model is training. Validation after 71 more training steps.)
# Epoch:  2 / 2 ..  Step: 135/205.. -- Time:    290.865   (Model is training. Validation after 70 more training steps.)
# Epoch:  2 / 2 ..  Step: 136/205.. -- Time:    291.665   (Model is training. Validation after 69 more training steps.)
# Epoch:  2 / 2 ..  Step: 137/205.. -- Time:    292.500   (Model is training. Validation after 68 more training steps.)
# Epoch:  2 / 2 ..  Step: 138/205.. -- Time:    293.244   (Model is training. Validation after 67 more training steps.)
# Epoch:  2 / 2 ..  Step: 139/205.. -- Time:    294.027   (Model is training. Validation after 66 more training steps.)
# Epoch:  2 / 2 ..  Step: 140/205.. -- Time:    294.823   (Model is training. Validation after 65 more training steps.)
# Epoch:  2 / 2 ..  Step: 141/205.. -- Time:    295.607   (Model is training. Validation after 64 more training steps.)
# Epoch:  2 / 2 ..  Step: 142/205.. -- Time:    296.400   (Model is training. Validation after 63 more training steps.)
# Epoch:  2 / 2 ..  Step: 143/205.. -- Time:    297.239   (Model is training. Validation after 62 more training steps.)
# Epoch:  2 / 2 ..  Step: 144/205.. -- Time:    298.090   (Model is training. Validation after 61 more training steps.)
# Epoch:  2 / 2 ..  Step: 145/205.. -- Time:    298.894   (Model is training. Validation after 60 more training steps.)
# Epoch:  2 / 2 ..  Step: 146/205.. -- Time:    299.673   (Model is training. Validation after 59 more training steps.)
# Epoch:  2 / 2 ..  Step: 147/205.. -- Time:    300.465   (Model is training. Validation after 58 more training steps.)
# Epoch:  2 / 2 ..  Step: 148/205.. -- Time:    301.216   (Model is training. Validation after 57 more training steps.)
# Epoch:  2 / 2 ..  Step: 149/205.. -- Time:    302.045   (Model is training. Validation after 56 more training steps.)
# Epoch:  2 / 2 ..  Step: 150/205.. -- Time:    302.892   (Model is training. Validation after 55 more training steps.)
# Epoch:  2 / 2 ..  Step: 151/205.. -- Time:    303.711   (Model is training. Validation after 54 more training steps.)
# Epoch:  2 / 2 ..  Step: 152/205.. -- Time:    304.474   (Model is training. Validation after 53 more training steps.)
# Epoch:  2 / 2 ..  Step: 153/205.. -- Time:    305.282   (Model is training. Validation after 52 more training steps.)
# Epoch:  2 / 2 ..  Step: 154/205.. -- Time:    306.058   (Model is training. Validation after 51 more training steps.)
# Epoch:  2 / 2 ..  Step: 155/205.. -- Time:    306.889   (Model is training. Validation after 50 more training steps.)
# Epoch:  2 / 2 ..  Step: 156/205.. -- Time:    307.709   (Model is training. Validation after 49 more training steps.)
# Epoch:  2 / 2 ..  Step: 157/205.. -- Time:    308.475   (Model is training. Validation after 48 more training steps.)
# Epoch:  2 / 2 ..  Step: 158/205.. -- Time:    309.270   (Model is training. Validation after 47 more training steps.)
# Epoch:  2 / 2 ..  Step: 159/205.. -- Time:    310.068   (Model is training. Validation after 46 more training steps.)
# Epoch:  2 / 2 ..  Step: 160/205.. -- Time:    310.848   (Model is training. Validation after 45 more training steps.)
# Epoch:  2 / 2 ..  Step: 161/205.. -- Time:    311.636   (Model is training. Validation after 44 more training steps.)
# Epoch:  2 / 2 ..  Step: 162/205.. -- Time:    312.388   (Model is training. Validation after 43 more training steps.)
# Epoch:  2 / 2 ..  Step: 163/205.. -- Time:    313.189   (Model is training. Validation after 42 more training steps.)
# Epoch:  2 / 2 ..  Step: 164/205.. -- Time:    314.026   (Model is training. Validation after 41 more training steps.)
# Epoch:  2 / 2 ..  Step: 165/205.. -- Time:    314.817   (Model is training. Validation after 40 more training steps.)
# Epoch:  2 / 2 ..  Step: 166/205.. -- Time:    315.621   (Model is training. Validation after 39 more training steps.)
# Epoch:  2 / 2 ..  Step: 167/205.. -- Time:    316.430   (Model is training. Validation after 38 more training steps.)
# Epoch:  2 / 2 ..  Step: 168/205.. -- Time:    317.282   (Model is training. Validation after 37 more training steps.)
# Epoch:  2 / 2 ..  Step: 169/205.. -- Time:    318.121   (Model is training. Validation after 36 more training steps.)
# Epoch:  2 / 2 ..  Step: 170/205.. -- Time:    318.936   (Model is training. Validation after 35 more training steps.)
# Epoch:  2 / 2 ..  Step: 171/205.. -- Time:    319.759   (Model is training. Validation after 34 more training steps.)
# Epoch:  2 / 2 ..  Step: 172/205.. -- Time:    320.598   (Model is training. Validation after 33 more training steps.)
# Epoch:  2 / 2 ..  Step: 173/205.. -- Time:    321.401   (Model is training. Validation after 32 more training steps.)
# Epoch:  2 / 2 ..  Step: 174/205.. -- Time:    322.212   (Model is training. Validation after 31 more training steps.)
# Epoch:  2 / 2 ..  Step: 175/205.. -- Time:    323.034   (Model is training. Validation after 30 more training steps.)
# Epoch:  2 / 2 ..  Step: 176/205.. -- Time:    323.831   (Model is training. Validation after 29 more training steps.)
# Epoch:  2 / 2 ..  Step: 177/205.. -- Time:    324.718   (Model is training. Validation after 28 more training steps.)
# Epoch:  2 / 2 ..  Step: 178/205.. -- Time:    325.557   (Model is training. Validation after 27 more training steps.)
# Epoch:  2 / 2 ..  Step: 179/205.. -- Time:    326.368   (Model is training. Validation after 26 more training steps.)
# Epoch:  2 / 2 ..  Step: 180/205.. -- Time:    327.170   (Model is training. Validation after 25 more training steps.)
# Epoch:  2 / 2 ..  Step: 181/205.. -- Time:    327.979   (Model is training. Validation after 24 more training steps.)
# Epoch:  2 / 2 ..  Step: 182/205.. -- Time:    328.806   (Model is training. Validation after 23 more training steps.)
# Epoch:  2 / 2 ..  Step: 183/205.. -- Time:    329.617   (Model is training. Validation after 22 more training steps.)
# Epoch:  2 / 2 ..  Step: 184/205.. -- Time:    330.442   (Model is training. Validation after 21 more training steps.)
# Epoch:  2 / 2 ..  Step: 185/205.. -- Time:    331.235   (Model is training. Validation after 20 more training steps.)
# Epoch:  2 / 2 ..  Step: 186/205.. -- Time:    332.050   (Model is training. Validation after 19 more training steps.)
# Epoch:  2 / 2 ..  Step: 187/205.. -- Time:    332.864   (Model is training. Validation after 18 more training steps.)
# Epoch:  2 / 2 ..  Step: 188/205.. -- Time:    333.651   (Model is training. Validation after 17 more training steps.)
# Epoch:  2 / 2 ..  Step: 189/205.. -- Time:    334.455   (Model is training. Validation after 16 more training steps.)
# Epoch:  2 / 2 ..  Step: 190/205.. -- Time:    335.278   (Model is training. Validation after 15 more training steps.)
# Epoch:  2 / 2 ..  Step: 191/205.. -- Time:    336.083   (Model is training. Validation after 14 more training steps.)
# Epoch:  2 / 2 ..  Step: 192/205.. -- Time:    336.873   (Model is training. Validation after 13 more training steps.)
# Epoch:  2 / 2 ..  Step: 193/205.. -- Time:    337.644   (Model is training. Validation after 12 more training steps.)
# Epoch:  2 / 2 ..  Step: 194/205.. -- Time:    338.486   (Model is training. Validation after 11 more training steps.)
# Epoch:  2 / 2 ..  Step: 195/205.. -- Time:    339.284   (Model is training. Validation after 10 more training steps.)
# Epoch:  2 / 2 ..  Step: 196/205.. -- Time:    340.065   (Model is training. Validation after 9 more training steps.)
# Epoch:  2 / 2 ..  Step: 197/205.. -- Time:    340.864   (Model is training. Validation after 8 more training steps.)
# Epoch:  2 / 2 ..  Step: 198/205.. -- Time:    341.651   (Model is training. Validation after 7 more training steps.)
# Epoch:  2 / 2 ..  Step: 199/205.. -- Time:    342.437   (Model is training. Validation after 6 more training steps.)
# Epoch:  2 / 2 ..  Step: 200/205.. -- Time:    343.230   (Model is training. Validation after 5 more training steps.)
# Epoch:  2 / 2 ..  Step: 201/205.. -- Time:    344.049   (Model is training. Validation after 4 more training steps.)
# Epoch:  2 / 2 ..  Step: 202/205.. -- Time:    344.877   (Model is training. Validation after 3 more training steps.)
# Epoch:  2 / 2 ..  Step: 203/205.. -- Time:    345.663   (Model is training. Validation after 2 more training steps.)
# Epoch:  2 / 2 ..  Step: 204/205.. -- Time:    346.481   (Model is training. Validation after 1 more training steps.)
# Epoch:  2 / 2 ..  Step: 205/205.. -- Time:    347.204   (Model is training. Validation after 0 more training steps.)
# Epoch:  2 / 2 ..  Step: 205/205.. -- Time:    367.366 Training Loss: 2.534..  Test Loss: 1.671..  Test Accuracy: 0.562

# %% [markdown]
# ## Save the trained network here:

# %%
# save the model and hyperparameters
save_path = 'model_checkpoints/checkpoint.pth'
save_checkpoint(save_path, model, hyperparameters['architecture'], 
                model.classifier.hidden_layers[0].in_features, 
                model.classifier.output.out_features, 
                hyperparameters, model_accuracy)

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# DONE: Do validation on the test set
# check the current model accuracy by doing a forward pass

# Put the model in eval mode and turn off gradients
model.eval()
eval_start = time.time()
with torch.no_grad():
    # Do a validation
    test_loss, accuracy = validation(model, test_dataloader, criterion, device)
eval_time = time.time()-eval_start
# Print the results to the output window
print("Test Loss: {:.3f}.. ".format(test_loss/len(test_dataloader)),
      "Test Accuracy: {:.3f}".format(accuracy/len(test_dataloader)),
      "-- Time: {:>10.3f}".format(eval_time)
     )
# Out:
# Test Loss: 1.677..  Test Accuracy: 0.559 -- Time:     19.537

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# DONE: Save the checkpoint 
# save the model and hyperparameters
save_path = 'model_checkpoints/checkpoint.pth'
save_checkpoint(save_path, model, hyperparameters['architecture'], 
                model.classifier.hidden_layers[0].in_features, 
                model.classifier.output.out_features, 
                hyperparameters, model_accuracy)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# DONE: Write a function that loads a checkpoint and rebuilds the model
# if a model is already saved, load it now
model, accuracy = load_checkpoint('model_checkpoints/checkpoint.pth')

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(pil_image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # DONE: Process a PIL image for use in a PyTorch model
    
    # define transforms
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    
    # preprocess the image
    img_tensor = preprocess(pil_image)
    
    # add dimension for batch
    img_tensor.unsqueeze_(0)
    
    return img_tensor

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
# get a random image from the valid directory
category = str(np.random.randint(1, len(cat_to_name)))
directory = valid_dir + "/" + category
files = os.listdir(directory)
idx = np.random.randint(0, len(files))
image_path = directory + "/" + files[idx]
print(image_path)
# Out:
# flowers/valid/56/image_02805.jpg

# %%
# open the image with PIL and display it with imshow()
image = process_image(Image.open(image_path))
imshow(image[0])

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, use_GPU, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # DONE: Implement the code to predict the class from an image file
    image = process_image(Image.open(image_path))
    
    if(use_GPU==True):
        if torch.cuda.is_available():
            device = torch.device("cuda:0")
        else:
            print("GPU not available. Using CPU instead.")
            device = torch.device("cpu")
    else:
        device = torch.device("cpu")
    print(f"Device = {device}\n")

    # do a forward pass on the image
    model.eval()
    model.to(device)
    criterion = nn.NLLLoss()
    #optimizer = optim.Adam(model.classifier.parameters(), lr=learnrate)
    image = image.to(device)
    with torch.no_grad():
        output = model.forward(image)
        ps = torch.exp(output)

    topk_probs_tensor, topk_idx_tensor = ps.topk(topk)

    #probs = topk_probs_tensor.tolist()[0]
    #classes = [model.class_to_idx[str(sorted(model.class_to_idx)[i])] for i in (topk_idx_tensor).tolist()[0]]
    
    return topk_probs_tensor, topk_idx_tensor #probs, classes

# %%
# get the probabilities and classes
top_k = 5
probs_tensor, classes_tensor = predict(image_path, model, use_GPU=True, topk=top_k)

# Convert the probabilities and classes tensors into lists
probs = probs_tensor.tolist()[0]
model.class_to_idx = cat_to_name
classes = [model.class_to_idx[str(sorted(model.class_to_idx)[i])] for i in (classes_tensor).tolist()[0]]

print(probs)
print(classes)
# Out:
# Device = cuda:0
#
# [0.6111067533493042, 0.08397594839334488, 0.041541937738657, 0.040264636278152466, 0.0328175313770771]
# ['bishop of llandaff', 'wallflower', 'canna lily', 'trumpet creeper', 'bromelia']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# DONE: Display an image along with the top 5 classes
#fig, (ax1, ax2) = plt.subplots(figsize=(4,9), nrows=2)
#ax1 = imshow(image[0], ax1)
#ax1.axis('off')
#ax1.set_title(model.class_to_idx[str(category)])
#ax2.barh(-np.arange(5), probs, tick_label=classes)


# Plot the image and the top k probabilities in a horizontal bar chart
fig, (ax1, ax2) = plt.subplots(figsize=(10,10), nrows=2)
ax1 = imshow(image[0], ax1)
ax1.axis('off')
ax1.set_title("Input Image: {}".format(model.class_to_idx[str(category)]))
ax2.barh(-np.arange(top_k), probs, tick_label=classes)
ax2.set_title("Predicted Class:\n(model accuracy: {:.3f})".format(accuracy))
ax2.set_xlabel('Probability')
ax2.set_ylabel('Category')
plt.show()
